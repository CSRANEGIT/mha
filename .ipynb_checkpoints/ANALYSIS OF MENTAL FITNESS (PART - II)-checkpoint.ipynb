# %% [markdown]
# # ANALYSIS OF MENTAL FITNESS (PART - II)

# %%
import pandas as pd
import numpy as np
import matplotlib as mp
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# PreProcessing
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import SimpleImputer, IterativeImputer
from sklearn.preprocessing import MinMaxScaler, StandardScaler


# Splitting Data
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score

# Modeling
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, recall_score, plot_roc_curve
from sklearn.ensemble import AdaBoostClassifier, ExtraTreesClassifier

# Tuning
from sklearn.model_selection import RandomizedSearchCV

# Deployment
import pickle

# %%
df = pd.read_csv('survey.csv')
pd.set_option("display.max_rows", None)

# %%
df.shape
# Out:
# (1259, 27)

# %%
df.drop(columns=['Timestamp', 'Country', 'state', 'comments'], inplace = True)

# %%
df.rename({'self_employed' : 'Self_Employed', 'family_history' : 'Family_History', 
           'treatment' : 'Treatment', 'work_interfere' : 'Work_Interfere', 
           'no_employees': 'Employee_Numbers', 'remote_work': 'Remote_Work', 'tech_company': 'Tech_Company', 
           'benefits': 'Benefits', 'care_options': 'Care_Options', 'wellness_program': 'Wellness_Program', 
           'seek_help': 'Seek_Help', 'anonymity': 'Anonymity', 'leave': 'Medical_Leave', 
           'mental_health_consequence': 'Mental_Health_Consequence', 
           'phys_health_consequence': 'Physical_Health_Consequence', 'coworkers': 'Coworkers', 
           'supervisor': 'Supervisor', 'mental_health_interview': 'Mental_Health_Interview', 
           'phys_health_interview': 'Physical_Health_Interview', 'mental_vs_physical': 'Mental_VS_Physical', 
           'obs_consequence': 'Observed_Consequence'} , inplace = True , axis = 1)

# %%
df['Gender'].replace(['Male ', 'male', 'M', 'm', 'Male', 'Cis Male',
                     'Man', 'cis male', 'Mail', 'Male-ish', 'Male (CIS)',
                      'Cis Man', 'msle', 'Malr', 'Mal', 'maile', 'Make',], 'Male', inplace = True)

df['Gender'].replace(['Female ', 'female', 'F', 'f', 'Woman', 'Female',
                     'femail', 'Cis Female', 'cis-female/femme', 'Femake', 'Female (cis)',
                     'woman',], 'Female', inplace = True)

df["Gender"].replace(['Female (trans)', 'queer/she/they', 'non-binary',
                     'fluid', 'queer', 'Androgyne', 'Trans-female', 'male leaning androgynous',
                      'Agender', 'A little about you', 'Nah', 'All',
                      'ostensibly male, unsure what that really means',
                      'Genderqueer', 'Enby', 'p', 'Neuter', 'something kinda male?',
                      'Guy (-ish) ^_^', 'Trans woman',], 'Queer', inplace = True)

# %%
defaultString = 'NaN'
df['Self_Employed'] = df['Self_Employed'].fillna(defaultString)
df['Self_Employed'] = df['Self_Employed'].replace([defaultString], 'No')
print(df['Self_Employed'].unique())
# Out:
# ['No' 'Yes']

# %%
df['Age'].replace([df['Age'][df['Age'] < 15]], np.nan, inplace = True)
df['Age'].replace([df['Age'][df['Age'] > 100]], np.nan, inplace = True)

df['Age'].unique()
# Out:
# array([37., 44., 32., 31., 33., 35., 39., 42., 23., 29., 36., 27., 46.,
#        41., 34., 30., 40., 38., 50., 24., 18., 28., 26., 22., 19., 25.,
#        45., 21., nan, 43., 56., 60., 54., 55., 48., 20., 57., 58., 47.,
#        62., 51., 65., 49., 53., 61., 72.])

# %% [markdown]
# ### PRE-PROCESSING

# %%
mode_onehot_pipe = Pipeline([
    ('encoder', SimpleImputer(strategy = 'most_frequent')),
    ('one hot encoder', OneHotEncoder(handle_unknown = 'ignore'))])

transformer = ColumnTransformer([
    ('one hot', OneHotEncoder(handle_unknown = 'ignore'), ['Gender', 'Family_History', 'Employee_Numbers',
                                                           'Remote_Work', 'Tech_Company', 'Benefits', 'Care_Options',
                                                           'Wellness_Program', 'Seek_Help', 'Anonymity',
                                                           'Medical_Leave', 'Mental_Health_Consequence',
                                                           'Physical_Health_Consequence', 'Coworkers', 'Supervisor',
                                                           'Mental_Health_Interview', 'Physical_Health_Interview',
                                                           'Mental_VS_Physical', 'Observed_Consequence']),
    ('mode_onehot_pipe', mode_onehot_pipe, ['Self_Employed', 'Work_Interfere']),
    ('iterative', IterativeImputer(max_iter = 10, random_state = 0), ['Age'])])

# %%
df['Gender']
# Out:
# 0       Female
# 1         Male
# 2         Male
# 3         Male
# 4         Male
# 5         Male
# 6       Female
# 7         Male
# 8       Female
# 9         Male
# 10        Male
# 11        Male
# 12      Female
# 13        Male
# 14        Male
# 15      Female
# 16        Male
# 17        Male
# 18        Male
# 19        Male
# 20        Male
# 21        Male
# 22        Male
# 23        Male
# 24        Male
# 25        Male
# 26        Male
# 27      Female
# 28        Male
# 29        Male
# 30        Male
# 31        Male
# 32        Male
# 33        Male
# 34      Female
# 35        Male
# 36        Male
# 37        Male
# 38        Male
# 39        Male
# 40        Male
# 41        Male
# 42        Male
# 43        Male
# 44        Male
# 45      Female
# 46        Male
# 47        Male
# 48        Male
# 49        Male
# 50        Male
# 51        Male
# 52        Male
# 53        Male
# 54        Male
# 55        Male
# 56        Male
# 57        Male
# 58        Male
# 59        Male
# 60        Male
# 61      Female
# 62        Male
# 63        Male
# 64        Male
# 65        Male
# 66      Female
# 67        Male
# 68      Female
# 69        Male
# 70        Male
# 71        Male
# 72       Queer
# 73        Male
# 74        Male
# 75        Male
# 76        Male
# 77        Male
# 78        Male
# 79        Male
# 80        Male
# 81        Male
# 82        Male
# 83      Female
# 84        Male
# 85        Male
# 86        Male
# 87      Female
# 88      Female
# 89        Male
# 90        Male
# 91        Male
# 92        Male
# 93       Queer
# 94      Female
# 95        Male
# 96        Male
# 97        Male
# 98        Male
# 99        Male
# 100     Female
# 101     Female
# 102       Male
# 103       Male
# 104       Male
# 105       Male
# 106       Male
# 107       Male
# 108       Male
# 109       Male
# 110       Male
# 111       Male
# 112       Male
# 113       Male
# 114       Male
# 115       Male
# 116       Male
# 117       Male
# 118       Male
# 119       Male
# 120       Male
# 121       Male
# 122       Male
# 123       Male
# 124       Male
# 125       Male
# 126       Male
# 127       Male
# 128       Male
# 129       Male
# 130       Male
# 131       Male
# 132       Male
# 133       Male
# 134       Male
# 135       Male
# 136       Male
# 137       Male
# 138     Female
# 139       Male
# 140       Male
# 141       Male
# 142       Male
# 143       Male
# 144     Female
# 145       Male
# 146       Male
# 147       Male
# 148       Male
# 149     Female
# 150       Male
# 151       Male
# 152       Male
# 153       Male
# 154       Male
# 155       Male
# 156       Male
# 157       Male
# 158       Male
# 159       Male
# 160       Male
# 161     Female
# 162       Male
# 163       Male
# 164     Female
# 165     Female
# 166       Male
# 167       Male
# 168       Male
# 169       Male
# 170       Male
# 171       Male
# 172       Male
# 173     Female
# 174     Female
# 175       Male
# 176       Male
# 177     Female
# 178     Female
# 179       Male
# 180       Male
# 181     Female
# 182     Female
# 183       Male
# 184       Male
# 185       Male
# 186       Male
# 187       Male
# 188       Male
# 189     Female
# 190     Female
# 191       Male
# 192       Male
# 193       Male
# 194     Female
# 195       Male
# 196     Female
# 197       Male
# 198       Male
# 199       Male
# 200     Female
# 201     Female
# 202       Male
# 203       Male
# 204       Male
# 205       Male
# 206       Male
# 207       Male
# 208       Male
# 209       Male
# 210     Female
# 211       Male
# 212       Male
# 213     Female
# 214     Female
# 215     Female
# 216       Male
# 217       Male
# 218     Female
# 219       Male
# 220     Female
# 221       Male
# 222       Male
# 223       Male
# 224       Male
# 225       Male
# 226       Male
# 227       Male
# 228       Male
# 229       Male
# 230       Male
# 231       Male
# 232       Male
# 233       Male
# 234       Male
# 235       Male
# 236       Male
# 237       Male
# 238     Female
# 239     Female
# 240       Male
# 241       Male
# 242       Male
# 243       Male
# 244       Male
# 245       Male
# 246       Male
# 247       Male
# 248       Male
# 249     Female
# 250       Male
# 251       Male
# 252       Male
# 253       Male
# 254       Male
# 255       Male
# 256     Female
# 257       Male
# 258       Male
# 259       Male
# 260     Female
# 261       Male
# 262       Male
# 263       Male
# 264       Male
# 265       Male
# 266       Male
# 267       Male
# 268     Female
# 269       Male
# 270       Male
# 271     Female
# 272       Male
# 273       Male
# 274       Male
# 275       Male
# 276       Male
# 277       Male
# 278       Male
# 279       Male
# 280       Male
# 281       Male
# 282       Male
# 283       Male
# 284       Male
# 285       Male
# 286     Female
# 287       Male
# 288     Female
# 289     Female
# 290       Male
# 291       Male
# 292       Male
# 293       Male
# 294       Male
# 295     Female
# 296     Female
# 297       Male
# 298       Male
# 299       Male
# 300     Female
# 301     Female
# 302       Male
# 303     Female
# 304     Female
# 305       Male
# 306      Queer
# 307       Male
# 308       Male
# 309       Male
# 310       Male
# 311       Male
# 312       Male
# 313       Male
# 314       Male
# 315       Male
# 316       Male
# 317       Male
# 318     Female
# 319       Male
# 320       Male
# 321       Male
# 322       Male
# 323     Female
# 324       Male
# 325       Male
# 326     Female
# 327       Male
# 328       Male
# 329       Male
# 330       Male
# 331       Male
# 332       Male
# 333       Male
# 334       Male
# 335       Male
# 336       Male
# 337     Female
# 338       Male
# 339       Male
# 340       Male
# 341     Female
# 342       Male
# 343       Male
# 344       Male
# 345     Female
# 346       Male
# 347       Male
# 348       Male
# 349      Queer
# 350       Male
# 351       Male
# 352       Male
# 353       Male
# 354     Female
# 355       Male
# 356       Male
# 357       Male
# 358       Male
# 359       Male
# 360     Female
# 361       Male
# 362       Male
# 363       Male
# 364       Male
# 365       Male
# 366       Male
# 367       Male
# 368       Male
# 369       Male
# 370     Female
# 371       Male
# 372       Male
# 373     Female
# 374     Female
# 375       Male
# 376     Female
# 377     Female
# 378     Female
# 379     Female
# 380       Male
# 381       Male
# 382       Male
# 383       Male
# 384       Male
# 385     Female
# 386       Male
# 387      Queer
# 388     Female
# 389     Female
# 390      Queer
# 391     Female
# 392       Male
# 393       Male
# 394     Female
# 395       Male
# 396       Male
# 397       Male
# 398     Female
# 399       Male
# 400       Male
# 401       Male
# 402       Male
# 403       Male
# 404       Male
# 405       Male
# 406       Male
# 407       Male
# 408       Male
# 409     Female
# 410       Male
# 411     Female
# 412       Male
# 413      Queer
# 414     Female
# 415       Male
# 416      Queer
# 417       Male
# 418       Male
# 419       Male
# 420       Male
# 421       Male
# 422       Male
# 423       Male
# 424     Female
# 425       Male
# 426       Male
# 427     Female
# 428       Male
# 429     Female
# 430       Male
# 431     Female
# 432       Male
# 433       Male
# 434     Female
# 435       Male
# 436       Male
# 437       Male
# 438     Female
# 439       Male
# 440       Male
# 441       Male
# 442       Male
# 443     Female
# 444       Male
# 445       Male
# 446       Male
# 447     Female
# 448       Male
# 449       Male
# 450       Male
# 451      Queer
# 452       Male
# 453       Male
# 454       Male
# 455       Male
# 456       Male
# 457       Male
# 458       Male
# 459       Male
# 460       Male
# 461     Female
# 462       Male
# 463     Female
# 464       Male
# 465       Male
# 466       Male
# 467       Male
# 468       Male
# 469     Female
# 470       Male
# 471       Male
# 472       Male
# 473     Female
# 474       Male
# 475       Male
# 476       Male
# 477       Male
# 478       Male
# 479     Female
# 480       Male
# 481       Male
# 482     Female
# 483       Male
# 484       Male
# 485       Male
# 486     Female
# 487       Male
# 488       Male
# 489       Male
# 490       Male
# 491       Male
# 492       Male
# 493     Female
# 494       Male
# 495     Female
# 496       Male
# 497     Female
# 498       Male
# 499       Male
# 500     Female
# 501       Male
# 502       Male
# 503       Male
# 504     Female
# 505       Male
# 506       Male
# 507       Male
# 508       Male
# 509       Male
# 510     Female
# 511     Female
# 512       Male
# 513       Male
# 514       Male
# 515       Male
# 516       Male
# 517     Female
# 518       Male
# 519       Male
# 520       Male
# 521     Female
# 522       Male
# 523       Male
# 524       Male
# 525     Female
# 526       Male
# 527       Male
# 528       Male
# 529     Female
# 530       Male
# 531       Male
# 532     Female
# 533       Male
# 534       Male
# 535     Female
# 536       Male
# 537       Male
# 538       Male
# 539     Female
# 540     Female
# 541     Female
# 542       Male
# 543     Female
# 544      Queer
# 545     Female
# 546       Male
# 547       Male
# 548       Male
# 549       Male
# 550     Female
# 551       Male
# 552     Female
# 553      Queer
# 554     Female
# 555     Female
# 556       Male
# 557       Male
# 558       Male
# 559       Male
# 560       Male
# 561       Male
# 562       Male
# 563       Male
# 564       Male
# 565       Male
# 566       Male
# 567       Male
# 568       Male
# 569       Male
# 570       Male
# 571       Male
# 572     Female
# 573     Female
# 574       Male
# 575       Male
# 576       Male
# 577       Male
# 578       Male
# 579       Male
# 580       Male
# 581       Male
# 582       Male
# 583       Male
# 584       Male
# 585     Female
# 586       Male
# 587     Female
# 588       Male
# 589       Male
# 590       Male
# 591       Male
# 592       Male
# 593       Male
# 594       Male
# 595       Male
# 596     Female
# 597       Male
# 598       Male
# 599       Male
# 600       Male
# 601       Male
# 602       Male
# 603     Female
# 604       Male
# 605       Male
# 606       Male
# 607       Male
# 608       Male
# 609       Male
# 610       Male
# 611       Male
# 612       Male
# 613       Male
# 614       Male
# 615       Male
# 616       Male
# 617       Male
# 618       Male
# 619       Male
# 620       Male
# 621       Male
# 622     Female
# 623     Female
# 624     Female
# 625     Female
# 626      Queer
# 627       Male
# 628      Queer
# 629       Male
# 630     Female
# 631       Male
# 632       Male
# 633     Female
# 634       Male
# 635       Male
# 636       Male
# 637       Male
# 638       Male
# 639       Male
# 640       Male
# 641       Male
# 642     Female
# 643       Male
# 644     Female
# 645       Male
# 646       Male
# 647       Male
# 648     Female
# 649     Female
# 650       Male
# 651       Male
# 652       Male
# 653     Female
# 654       Male
# 655       Male
# 656       Male
# 657       Male
# 658       Male
# 659       Male
# 660     Female
# 661       Male
# 662       Male
# 663       Male
# 664       Male
# 665       Male
# 666       Male
# 667       Male
# 668       Male
# 669       Male
# 670       Male
# 671       Male
# 672       Male
# 673     Female
# 674       Male
# 675       Male
# 676       Male
# 677     Female
# 678       Male
# 679       Male
# 680       Male
# 681       Male
# 682      Queer
# 683     Female
# 684     Female
# 685     Female
# 686     Female
# 687       Male
# 688       Male
# 689     Female
# 690       Male
# 691       Male
# 692       Male
# 693     Female
# 694       Male
# 695       Male
# 696       Male
# 697     Female
# 698       Male
# 699       Male
# 700       Male
# 701       Male
# 702       Male
# 703       Male
# 704       Male
# 705       Male
# 706       Male
# 707       Male
# 708     Female
# 709       Male
# 710       Male
# 711       Male
# 712       Male
# 713       Male
# 714       Male
# 715       Male
# 716       Male
# 717       Male
# 718       Male
# 719       Male
# 720       Male
# 721       Male
# 722       Male
# 723       Male
# 724       Male
# 725       Male
# 726       Male
# 727       Male
# 728       Male
# 729       Male
# 730       Male
# 731       Male
# 732       Male
# 733       Male
# 734       Male
# 735       Male
# 736       Male
# 737       Male
# 738       Male
# 739       Male
# 740       Male
# 741       Male
# 742       Male
# 743       Male
# 744       Male
# 745       Male
# 746       Male
# 747       Male
# 748       Male
# 749       Male
# 750       Male
# 751       Male
# 752       Male
# 753       Male
# 754       Male
# 755     Female
# 756     Female
# 757       Male
# 758       Male
# 759       Male
# 760       Male
# 761     Female
# 762       Male
# 763       Male
# 764     Female
# 765       Male
# 766     Female
# 767       Male
# 768     Female
# 769       Male
# 770       Male
# 771       Male
# 772       Male
# 773       Male
# 774       Male
# 775       Male
# 776       Male
# 777      Queer
# 778     Female
# 779     Female
# 780       Male
# 781       Male
# 782       Male
# 783       Male
# 784       Male
# 785       Male
# 786       Male
# 787       Male
# 788       Male
# 789       Male
# 790       Male
# 791       Male
# 792     Female
# 793     Female
# 794     Female
# 795       Male
# 796     Female
# 797       Male
# 798       Male
# 799     Female
# 800       Male
# 801       Male
# 802       Male
# 803     Female
# 804       Male
# 805      Queer
# 806     Female
# 807     Female
# 808       Male
# 809       Male
# 810       Male
# 811       Male
# 812       Male
# 813       Male
# 814     Female
# 815     Female
# 816       Male
# 817       Male
# 818      Queer
# 819       Male
# 820     Female
# 821       Male
# 822       Male
# 823       Male
# 824       Male
# 825     Female
# 826       Male
# 827       Male
# 828     Female
# 829       Male
# 830       Male
# 831       Male
# 832       Male
# 833     Female
# 834       Male
# 835       Male
# 836     Female
# 837     Female
# 838       Male
# 839       Male
# 840       Male
# 841       Male
# 842     Female
# 843       Male
# 844       Male
# 845       Male
# 846       Male
# 847       Male
# 848       Male
# 849       Male
# 850       Male
# 851       Male
# 852       Male
# 853       Male
# 854       Male
# 855       Male
# 856       Male
# 857       Male
# 858       Male
# 859       Male
# 860       Male
# 861       Male
# 862       Male
# 863       Male
# 864       Male
# 865       Male
# 866       Male
# 867       Male
# 868       Male
# 869       Male
# 870       Male
# 871     Female
# 872       Male
# 873       Male
# 874       Male
# 875       Male
# 876       Male
# 877       Male
# 878     Female
# 879       Male
# 880       Male
# 881       Male
# 882       Male
# 883       Male
# 884       Male
# 885       Male
# 886       Male
# 887       Male
# 888       Male
# 889       Male
# 890       Male
# 891       Male
# 892       Male
# 893       Male
# 894       Male
# 895       Male
# 896       Male
# 897       Male
# 898       Male
# 899       Male
# 900       Male
# 901       Male
# 902     Female
# 903       Male
# 904       Male
# 905       Male
# 906       Male
# 907     Female
# 908       Male
# 909       Male
# 910       Male
# 911       Male
# 912     Female
# 913       Male
# 914     Female
# 915       Male
# 916       Male
# 917       Male
# 918       Male
# 919     Female
# 920       Male
# 921       Male
# 922       Male
# 923       Male
# 924       Male
# 925       Male
# 926       Male
# 927       Male
# 928       Male
# 929       Male
# 930     Female
# 931       Male
# 932       Male
# 933       Male
# 934       Male
# 935       Male
# 936       Male
# 937       Male
# 938       Male
# 939       Male
# 940       Male
# 941       Male
# 942     Female
# 943       Male
# 944       Male
# 945       Male
# 946       Male
# 947       Male
# 948       Male
# 949       Male
# 950       Male
# 951       Male
# 952       Male
# 953     Female
# 954       Male
# 955       Male
# 956       Male
# 957       Male
# 958       Male
# 959       Male
# 960       Male
# 961       Male
# 962       Male
# 963       Male
# 964       Male
# 965       Male
# 966     Female
# 967       Male
# 968       Male
# 969     Female
# 970       Male
# 971       Male
# 972       Male
# 973       Male
# 974       Male
# 975       Male
# 976       Male
# 977       Male
# 978       Male
# 979       Male
# 980       Male
# 981     Female
# 982     Female
# 983       Male
# 984       Male
# 985       Male
# 986     Female
# 987       Male
# 988       Male
# 989      Queer
# 990       Male
# 991       Male
# 992     Female
# 993       Male
# 994       Male
# 995       Male
# 996       Male
# 997     Female
# 998       Male
# 999       Male
# 1000      Male
# 1001      Male
# 1002      Male
# 1003    Female
# 1004      Male
# 1005      Male
# 1006      Male
# 1007      Male
# 1008      Male
# 1009    Female
# 1010      Male
# 1011    Female
# 1012    Female
# 1013    Female
# 1014      Male
# 1015      Male
# 1016    Female
# 1017     Queer
# 1018      Male
# 1019      Male
# 1020      Male
# 1021    Female
# 1022      Male
# 1023      Male
# 1024      Male
# 1025      Male
# 1026    Female
# 1027      Male
# 1028    Female
# 1029      Male
# 1030      Male
# 1031      Male
# 1032      Male
# 1033    Female
# 1034      Male
# 1035      Male
# 1036      Male
# 1037      Male
# 1038    Female
# 1039      Male
# 1040    Female
# 1041      Male
# 1042      Male
# 1043      Male
# 1044    Female
# 1045    Female
# 1046      Male
# 1047      Male
# 1048      Male
# 1049      Male
# 1050    Female
# 1051    Female
# 1052      Male
# 1053      Male
# 1054      Male
# 1055      Male
# 1056      Male
# 1057      Male
# 1058      Male
# 1059    Female
# 1060    Female
# 1061      Male
# 1062      Male
# 1063      Male
# 1064      Male
# 1065      Male
# 1066      Male
# 1067      Male
# 1068      Male
# 1069      Male
# 1070    Female
# 1071      Male
# 1072      Male
# 1073      Male
# 1074      Male
# 1075      Male
# 1076      Male
# 1077    Female
# 1078    Female
# 1079      Male
# 1080      Male
# 1081      Male
# 1082    Female
# 1083    Female
# 1084      Male
# 1085      Male
# 1086      Male
# 1087      Male
# 1088      Male
# 1089    Female
# 1090      Male
# 1091      Male
# 1092      Male
# 1093      Male
# 1094      Male
# 1095      Male
# 1096      Male
# 1097      Male
# 1098      Male
# 1099      Male
# 1100      Male
# 1101      Male
# 1102    Female
# 1103    Female
# 1104      Male
# 1105      Male
# 1106      Male
# 1107      Male
# 1108    Female
# 1109      Male
# 1110      Male
# 1111      Male
# 1112      Male
# 1113      Male
# 1114      Male
# 1115      Male
# 1116      Male
# 1117      Male
# 1118      Male
# 1119      Male
# 1120      Male
# 1121      Male
# 1122    Female
# 1123    Female
# 1124      Male
# 1125      Male
# 1126    Female
# 1127     Queer
# 1128      Male
# 1129      Male
# 1130    Female
# 1131      Male
# 1132    Female
# 1133      Male
# 1134      Male
# 1135      Male
# 1136      Male
# 1137      Male
# 1138      Male
# 1139      Male
# 1140      Male
# 1141      Male
# 1142      Male
# 1143    Female
# 1144      Male
# 1145    Female
# 1146      Male
# 1147      Male
# 1148      Male
# 1149      Male
# 1150      Male
# 1151      Male
# 1152      Male
# 1153    Female
# 1154      Male
# 1155      Male
# 1156      Male
# 1157      Male
# 1158      Male
# 1159      Male
# 1160      Male
# 1161      Male
# 1162      Male
# 1163      Male
# 1164    Female
# 1165      Male
# 1166      Male
# 1167      Male
# 1168      Male
# 1169    Female
# 1170      Male
# 1171      Male
# 1172    Female
# 1173      Male
# 1174      Male
# 1175      Male
# 1176    Female
# 1177      Male
# 1178      Male
# 1179    Female
# 1180    Female
# 1181      Male
# 1182    Female
# 1183    Female
# 1184    Female
# 1185    Female
# 1186    Female
# 1187      Male
# 1188    Female
# 1189      Male
# 1190      Male
# 1191      Male
# 1192      Male
# 1193      Male
# 1194      Male
# 1195    Female
# 1196    Female
# 1197      Male
# 1198      Male
# 1199      Male
# 1200      Male
# 1201    Female
# 1202      Male
# 1203      Male
# 1204      Male
# 1205      Male
# 1206      Male
# 1207      Male
# 1208      Male
# 1209      Male
# 1210      Male
# 1211      Male
# 1212    Female
# 1213      Male
# 1214      Male
# 1215      Male
# 1216      Male
# 1217      Male
# 1218      Male
# 1219      Male
# 1220      Male
# 1221      Male
# 1222    Female
# 1223      Male
# 1224      Male
# 1225    Female
# 1226      Male
# 1227    Female
# 1228      Male
# 1229      Male
# 1230    Female
# 1231      Male
# 1232      Male
# 1233      Male
# 1234     Queer
# 1235      Male
# 1236      Male
# 1237      Male
# 1238      Male
# 1239      Male
# 1240      Male
# 1241      Male
# 1242      Male
# 1243    Female
# 1244    Female
# 1245      Male
# 1246      Male
# 1247      Male
# 1248    Female
# 1249      Male
# 1250      Male
# 1251      Male
# 1252      Male
# 1253      Male
# 1254      Male
# 1255      Male
# 1256      Male
# 1257    Female
# 1258      Male
# Name: Gender, dtype: object

# %% [markdown]
# #### DEFINE THE TARGET DATA

# %%
df['Treatment'].value_counts()/df.shape[0]*100
# Out:
# Yes    50.595711
# No     49.404289
# Name: Treatment, dtype: float64

# %%
df['Treatment'] = np.where(df['Treatment'] == 'Yes', 1, 0)

# %% [markdown]
# 0 = No Treatment
# 1 = Gotten Treatment

# %%
X = df.drop('Treatment', axis = 1)
y = df['Treatment']

# %% [markdown]
# ### SPLITTING DATA

# %%
X.shape
# Out:
# (1259, 22)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,
                                                   stratify = y,
                                                    test_size = 0.3,
                                                   random_state = 0)

# %% [markdown]
# ### MODEL DEFINITION

# %%
logreg = LogisticRegression()
tree = DecisionTreeClassifier(random_state = 0)
ada = AdaBoostClassifier(random_state = 0)

# %% [markdown]
# ### MODEL EVALUATION

# %%
logreg_pipe = Pipeline([('transformer', transformer), ('logreg', logreg)])
tree_pipe = Pipeline([('transformer', transformer), ('tree', tree)])
ada_pipe = Pipeline([('transformer', transformer), ('ada', ada)])

def model_evaluation(model, metric):
    model_cv = cross_val_score(model, X_train, y_train, cv = StratifiedKFold(n_splits = 5), scoring = metric)
    return model_cv

logreg_pipe_cv = model_evaluation(logreg_pipe, 'accuracy')
tree_pipe_cv = model_evaluation(tree_pipe, 'accuracy')
ada_pipe_cv = model_evaluation(ada_pipe, 'accuracy')

for model in [logreg_pipe, tree_pipe, ada_pipe]:
    model.fit(X_train, y_train)

score_cv = [logreg_pipe_cv.round(5), tree_pipe_cv.round(5),  ada_pipe_cv.round(5)]

score_mean = [logreg_pipe_cv.mean(), tree_pipe_cv.mean(),  ada_pipe_cv.mean()]

score_std = [logreg_pipe_cv.std(), tree_pipe_cv.std(),  ada_pipe_cv.std()]

score_accuracy_score = [accuracy_score(y_test, logreg_pipe.predict(X_test)),
                      accuracy_score(y_test, tree_pipe.predict(X_test)), 
                      accuracy_score(y_test, ada_pipe.predict(X_test))]
  
method_name = ['Logistic Regression', 'Decision Tree Classifier',  'Ada Boost Classifier']

cv_summary = pd.DataFrame({
    'method': method_name,
    'cv score': score_cv,
    'mean score': score_mean,
    'std score': score_std,
    'accuracy score': score_accuracy_score
})
cv_summary
# Out:
#                      method                                       cv score  \
# 0       Logistic Regression   [0.74011, 0.74432, 0.6875, 0.72159, 0.77841]
# 1  Decision Tree Classifier  [0.71751, 0.70455, 0.63068, 0.63636, 0.72727]
# 2      Ada Boost Classifier  [0.75141, 0.71023, 0.68182, 0.72727, 0.74432]
#
#    mean score  std score  accuracy score
# 0    0.734386   0.029771        0.748677
# 1    0.683276   0.041297        0.648148
# 2    0.723010   0.025056        0.735450

# %% [markdown]
# ### HYPERPARAMETER TUNING

# %%
lr_estimator = Pipeline([
    ('transformer', transformer),
    ('model', logreg)])

hyperparam_space = {
    'model__C' : [1, 5, 10, 50, 100],
    'model__solver': ['newton-cg', 'lbfgs', 'liblinear'],
    'model__class_weight': ['balanced', 'dict'],
    'model__penalty':['none', 'l1', 'l2', 'elasticnet'],
    'model__random_state': [0]
}

rs_lr = RandomizedSearchCV(
                lr_estimator,
                hyperparam_space,
                cv = StratifiedKFold(n_splits = 5),
                scoring = 'accuracy',
                n_jobs = -1)

rs_lr.fit(X_train, y_train)

print('best score', rs_lr.best_score_)
print('best param', rs_lr.best_params_)
# Out:
# best score 0.7298536209553159
# best param {'model__solver': 'lbfgs', 'model__random_state': 0, 'model__penalty': 'none', 'model__class_weight': 'dict', 'model__C': 10}

# %%
logreg_pipe.fit(X_train, y_train)
accuracy_logreg = (accuracy_score(y_test, logreg_pipe.predict(X_test)))

rs_lr.best_estimator_.fit(X_train, y_train)
accuracy_grid = (accuracy_score(y_test, rs_lr.predict(X_test)))

score_list = [accuracy_logreg, accuracy_grid]
method_name = ['Logistic Regression Before Tuning','Logistic Regression After Tuning']
best_summary = pd.DataFrame({
    'method': method_name,
    'score': score_list
})
best_summary
# Out:
#                               method     score
# 0  Logistic Regression Before Tuning  0.748677
# 1   Logistic Regression After Tuning  0.748677

# %% [markdown]
# ### FEATURE SELECTION USING COEFFICIENT SCORE

# %%
transformer.transformers_
# Out:
# [('one hot',
#   OneHotEncoder(handle_unknown='ignore'),
#   ['Gender',
#    'Family_History',
#    'Employee_Numbers',
#    'Remote_Work',
#    'Tech_Company',
#    'Benefits',
#    'Care_Options',
#    'Wellness_Program',
#    'Seek_Help',
#    'Anonymity',
#    'Medical_Leave',
#    'Mental_Health_Consequence',
#    'Physical_Health_Consequence',
#    'Coworkers',
#    'Supervisor',
#    'Mental_Health_Interview',
#    'Physical_Health_Interview',
#    'Mental_VS_Physical',
#    'Observed_Consequence']),
#  ('mode_onehot_pipe',
#   Pipeline(steps=[('encoder', SimpleImputer(strategy='most_frequent')),
#                   ('one hot encoder', OneHotEncoder(handle_unknown='ignore'))]),
#   ['Self_Employed', 'Work_Interfere']),
#  ('iterative', IterativeImputer(random_state=0), ['Age'])]

# %%
transformer.transformers_[0][1].get_feature_names_out()
# Out:
# array(['Gender_Female', 'Gender_Male', 'Gender_Queer',
#        'Family_History_No', 'Family_History_Yes', 'Employee_Numbers_1-5',
#        'Employee_Numbers_100-500', 'Employee_Numbers_26-100',
#        'Employee_Numbers_500-1000', 'Employee_Numbers_6-25',
#        'Employee_Numbers_More than 1000', 'Remote_Work_No',
#        'Remote_Work_Yes', 'Tech_Company_No', 'Tech_Company_Yes',
#        "Benefits_Don't know", 'Benefits_No', 'Benefits_Yes',
#        'Care_Options_No', 'Care_Options_Not sure', 'Care_Options_Yes',
#        "Wellness_Program_Don't know", 'Wellness_Program_No',
#        'Wellness_Program_Yes', "Seek_Help_Don't know", 'Seek_Help_No',
#        'Seek_Help_Yes', "Anonymity_Don't know", 'Anonymity_No',
#        'Anonymity_Yes', "Medical_Leave_Don't know",
#        'Medical_Leave_Somewhat difficult', 'Medical_Leave_Somewhat easy',
#        'Medical_Leave_Very difficult', 'Medical_Leave_Very easy',
#        'Mental_Health_Consequence_Maybe', 'Mental_Health_Consequence_No',
#        'Mental_Health_Consequence_Yes',
#        'Physical_Health_Consequence_Maybe',
#        'Physical_Health_Consequence_No',
#        'Physical_Health_Consequence_Yes', 'Coworkers_No',
#        'Coworkers_Some of them', 'Coworkers_Yes', 'Supervisor_No',
#        'Supervisor_Some of them', 'Supervisor_Yes',
#        'Mental_Health_Interview_Maybe', 'Mental_Health_Interview_No',
#        'Mental_Health_Interview_Yes', 'Physical_Health_Interview_Maybe',
#        'Physical_Health_Interview_No', 'Physical_Health_Interview_Yes',
#        "Mental_VS_Physical_Don't know", 'Mental_VS_Physical_No',
#        'Mental_VS_Physical_Yes', 'Observed_Consequence_No',
#        'Observed_Consequence_Yes'], dtype=object)

# %%
transformer.transformers_[1][1][1].get_feature_names_out()
# Out:
# array(['x0_No', 'x0_Yes', 'x1_Never', 'x1_Often', 'x1_Rarely',
#        'x1_Sometimes'], dtype=object)

# %%
features = list(transformer.transformers_[0][1].get_feature_names())+list(transformer.transformers_[1][1][1].get_feature_names())+['Age']
coef_table = pd.DataFrame({'coef': rs_lr.best_estimator_[1].coef_.flatten()}, index = features)
abs(coef_table).sort_values('coef', ascending = False)
# Out:
#                             coef
# x1_Never                1.986361
# x1_Often                1.697422
# x10_Very difficult      0.735490
# x1_No                   0.652463
# x1_Yes                  0.640908
# x13_No                  0.639691
# x13_Yes                 0.584877
# x6_Yes                  0.552859
# x10_Somewhat easy       0.545552
# x0_Male                 0.506359
# x2_500-1000             0.488102
# x1_Rarely               0.476699
# x0_Queer                0.379892
# x2_1-5                  0.370194
# x5_Yes                  0.360274
# x6_Not sure             0.339318
# x10_Don't know          0.328457
# x11_No                  0.323751
# x10_Somewhat difficult  0.263361
# x5_No                   0.248982
# x15_Maybe               0.234016
# x6_No                   0.225096
# x12_Yes                 0.208407
# x15_No                  0.203963
# x8_Don't know           0.202974
# x1_Sometimes            0.199315
# x14_Yes                 0.195742
# x2_26-100               0.185071
# x2_More than 1000       0.179026
# x11_Yes                 0.176359
# x14_No                  0.167446
# x12_Maybe               0.162136
# x16_Yes                 0.155859
# x4_No                   0.136879
# x10_Very easy           0.136397
# x11_Maybe               0.135837
# x4_Yes                  0.125324
# x5_Don't know           0.122847
# x8_Yes                  0.122047
# x0_Female               0.114912
# x16_Maybe               0.107181
# x9_Don't know           0.105770
# x17_Yes                 0.103899
# x2_6-25                 0.096670
# x8_No                   0.092482
# x18_No                  0.078656
# x9_Yes                  0.072954
# x18_Yes                 0.067101
# x16_No                  0.060234
# x17_No                  0.059076
# x17_Don't know          0.056378
# x13_Some of them        0.043259
# x3_No                   0.039483
# x12_No                  0.034716
# x7_No                   0.028816
# x3_Yes                  0.027928
# Age                     0.026830
# x0_Yes                  0.021575
# x9_No                   0.021261
# x7_Don't know           0.020984
# x7_Yes                  0.019388
# x15_Yes                 0.018498
# x14_Some of them        0.016741
# x0_No                   0.010020
# x2_100-500              0.003639

# %%
abs(coef_table).plot(kind = 'barh', figsize = (20,20))
# Out:
# <AxesSubplot:>

# %%
df_tuning = df.copy()
df_tuning.drop(columns = ['Age', 'Remote_Work', 'Wellness_Program', 'Physical_Health_Consequence'], inplace = True)
df_tuning.head()
# Out:
#    Gender Self_Employed Family_History  Treatment Work_Interfere  \
# 0  Female            No             No          1          Often
# 1    Male            No             No          0         Rarely
# 2    Male            No             No          0         Rarely
# 3    Male            No            Yes          1          Often
# 4    Male            No             No          0          Never
#
#   Employee_Numbers Tech_Company    Benefits Care_Options   Seek_Help  \
# 0             6-25          Yes         Yes     Not sure         Yes
# 1   More than 1000           No  Don't know           No  Don't know
# 2             6-25          Yes          No           No          No
# 3           26-100          Yes          No          Yes          No
# 4          100-500          Yes         Yes           No  Don't know
#
#     Anonymity       Medical_Leave Mental_Health_Consequence     Coworkers  \
# 0         Yes       Somewhat easy                        No  Some of them
# 1  Don't know          Don't know                     Maybe            No
# 2  Don't know  Somewhat difficult                        No           Yes
# 3          No  Somewhat difficult                       Yes  Some of them
# 4  Don't know          Don't know                        No  Some of them
#
#   Supervisor Mental_Health_Interview Physical_Health_Interview  \
# 0        Yes                      No                     Maybe
# 1         No                      No                        No
# 2        Yes                     Yes                       Yes
# 3         No                   Maybe                     Maybe
# 4        Yes                     Yes                       Yes
#
#   Mental_VS_Physical Observed_Consequence
# 0                Yes                   No
# 1         Don't know                   No
# 2                 No                   No
# 3                 No                  Yes
# 4         Don't know                   No

# %%
mode_onehot_pipe_second = Pipeline([
    ('encoder', SimpleImputer(strategy = 'most_frequent')),
    ('one hot encoder', OneHotEncoder(handle_unknown = 'ignore'))])

transformer_second = ColumnTransformer([
    ('one hot', OneHotEncoder(handle_unknown = 'ignore'), ['Gender', 'Family_History', 'Employee_Numbers',
                                                           'Tech_Company', 'Benefits', 'Care_Options', 
                                                           'Seek_Help', 'Anonymity', 'Medical_Leave',
                                                           'Mental_Health_Consequence', 'Coworkers',
                                                           'Supervisor','Mental_Health_Interview',
                                                           'Physical_Health_Interview', 'Mental_VS_Physical',
                                                           'Observed_Consequence',]),
    ('mode_onehot_pipe', mode_onehot_pipe_second, ['Self_Employed', 'Work_Interfere']),])

# %%
X_select = df_tuning.drop('Treatment', axis = 1)
y_select = df_tuning['Treatment']

# %%
X_select_train, X_select_test, y_select_train, y_select_test = train_test_split(X_select,y_select,
                                                   stratify = y_select,
                                                    test_size = 0.3,
                                                   random_state = 2222)

# %% [markdown]
# ### RESULT

# %%
logreg_second = LogisticRegression(C = 0.5, class_weight = 'dict', max_iter = 100, multi_class = 'auto', random_state = 2222, solver = 'newton-cg')

logreg_second_pipe = Pipeline([('transformer', transformer_second), ('model', logreg_second)])

logreg_second_pipe.fit(X_select_train, y_select_train)

print('After Feature Selection Process, the score is ', accuracy_score(y_select_test, logreg_second_pipe.predict(X_select_test)))
# Out:
# After Feature Selection Process, the score is  0.7275132275132276

# %% [markdown]
# ### DEPLOYMENT

# %%
logreg_second_pipe.fit(X_select, y_select)

# %%
pickle_out = open("MentalHealthClassifier.pkl","wb")
pickle.dump(logreg_second_pipe, pickle_out)
pickle_out.close()

# %%
loaded_model = pickle.load(open('MentalHealthClassifier.pkl','rb'))
loaded_model.predict(X_select_test)

# %%
prediction = pd.DataFrame({
    'Gender': ['Male'],
    'Self_Employed': ['No'],
    'Family_History': ['No'],
    'Work_Interfere': ['Rarely'],
    'Employee_Numbers': ['More than 1000'],
    'Tech_Company': ['No'],
    'Benefits': ['Don\'t' 'know'],
    'Care_Options': ['No'],
    'Seek_Help': ['Don\'t ' 'know'],
    'Anonymity': ['Don\'t' 'know'],
    'Medical_Leave': ['Don\'t ' 'know'],
    'Mental_Health_Consequence': ['Maybe'],
    'Coworkers': ['No'],
    'Supervisor': ['No'],
    'Mental_Health_Interview': ['No'],
    'Physical_Health_Interview': ['No'],
    'Mental_VS_Physical': ['Don\'t ' 'know'],
    'Observed_Consequence': ['No']
})

# %%
prediction

# %%
loaded_model.predict(prediction)
